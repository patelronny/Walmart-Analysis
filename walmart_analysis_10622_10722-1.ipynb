# %% [markdown]
# # Walmart

# %% [markdown]
# ### Walmart is an American Multinational retail coorporation that operates a chain of hyper-markets, discount department stores, and grocery stores

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
train_df = pd.read_csv('train_walmart.csv')

# %%
features_df = pd.read_csv("features.csv")
stores_df = pd.read_csv("stores.csv")

# %%
train_df
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
features_df
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
stores_df
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...

# %%
train_df.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %%
features_df.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
stores_df.isnull().sum()
# Out:
# Store    0
# Type     0
# Size     0
# dtype: int64

# %%
## inner join
dataset_m = features_df.merge(stores_df,how='inner',on='Store')

# %%
features_df.shape
# Out:
# (8190, 12)

# %%
dataset_m.shape
# Out:
# (8190, 14)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
dataset_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8190 entries, 0 to 8189
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
#  12  Type          8190 non-null   object
#  13  Size          8190 non-null   int64
# dtypes: bool(1), float64(9), int64(2), object(2)
# memory usage: 903.8+ KB

# %%
from datetime import datetime
dataset_m['Date'] = pd.to_datetime(dataset_m['Date'])
train_df["Date"] = pd.to_datetime(train_df['Date'])

# %%
df = train_df.merge(dataset_m, how='inner',on = ['Store','Date','IsHoliday'])

# %%
df
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1 2010-02-05      24924.50      False        42.31
# 1           1     2 2010-02-05      50605.27      False        42.31
# 2           1     3 2010-02-05      13740.12      False        42.31
# 3           1     4 2010-02-05      39954.04      False        42.31
# 4           1     5 2010-02-05      32229.38      False        42.31
# ...       ...   ...        ...           ...        ...          ...
# 421565     45    93 2012-10-26       2487.80      False        58.85
# 421566     45    94 2012-10-26       5203.31      False        58.85
# 421567     45    95 2012-10-26      56017.47      False        58.85
# 421568     45    97 2012-10-26       6817.48      False        58.85
# 421569     45    98 2012-10-26       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# ...

# %%
df['week'] = df.Date.dt.isocalendar().week

# %%
df['year'] = df.Date.dt.isocalendar().year

# %%
df
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1 2010-02-05      24924.50      False        42.31
# 1           1     2 2010-02-05      50605.27      False        42.31
# 2           1     3 2010-02-05      13740.12      False        42.31
# 3           1     4 2010-02-05      39954.04      False        42.31
# 4           1     5 2010-02-05      32229.38      False        42.31
# ...       ...   ...        ...           ...        ...          ...
# 421565     45    93 2012-10-26       2487.80      False        58.85
# 421566     45    94 2012-10-26       5203.31      False        58.85
# 421567     45    95 2012-10-26      56017.47      False        58.85
# 421568     45    97 2012-10-26       6817.48      False        58.85
# 421569     45    98 2012-10-26       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# ...

# %% [raw]
# #################visualizations or eda
# #### make a function which will make a scatter plot and take arguments of df and column which we want to plot against weekly sales.

# %%
def scatter(dff,column):
    plt.figure(figsize=(12,8))
    plt.scatter(dff[column],dff['Weekly_Sales'])
    plt.ylabel('weekly sales')
    plt.xlabel(column)

# %%
scatter(df,'Store')

# %%
scatter(df,'Dept')

# %%
df.year.value_counts()
# Out:
# 2011    153453
# 2010    140679
# 2012    127438
# Name: year, dtype: Int64

# %% [raw]
# ####in year 2011 average weekly sales using a line plot ---------- filter the data of year 2011- groupby week and do average of sales - two columns

# %%
df['Weekly_Sales'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 421570 entries, 0 to 421569
# Series name: Weekly_Sales
# Non-Null Count   Dtype
# --------------   -----
# 421570 non-null  float64
# dtypes: float64(1)
# memory usage: 6.4 MB

# %%
weekly_sales_2011 = df[df['year']==2011].groupby(['week'])['Weekly_Sales'].mean()

# %%
weekly_sales_2011
# Out:
# week
# 1     14599.244973
# 2     13891.283484
# 3     13932.367385
# 4     13566.239462
# 5     15773.448776
# 6     16111.706191
# 7     16541.991212
# 8     15049.747558
# 9     15882.557045
# 10    15056.450540
# 11    15216.115961
# 12    14573.827050
# 13    14726.869261
# 14    15634.571312
# 15    15229.708141
# 16    16472.653827
# 17    14745.946064
# 18    15757.215296
# 19    15317.204186
# 20    15002.247279
# 21    15390.233449
# 22    16691.305332
# 23    16302.918830
# 24    16111.226407
# 25    15649.418342
# 26    16232.862334
# 27    16328.646803
# 28    15566.323502
# 29    15526.204180
# 30    14965.150490
# 31    16393.126313
# 32    15774.068626
# 33    15888.028317
# 34    16068.095036
# 35    15387.122167
# 36    15809.069483
# 37    14865.566897
# 38    14446.431089
# 39    14298.824402
# 40    15960.678959
# 41    15062.736015
# 42    15521.325691
# 43    15470.924781
# 44    16471.071192
# 45    16348.811046
# 46    15683.546288
# 47    22043.563476
# ...

# %%
sns.lineplot(weekly_sales_2011.index, weekly_sales_2011.values,color='red')
# Out:
# <AxesSubplot:xlabel='week'>

# %%
weekly_sales_2010 = df[df['year']==2010].groupby(['week'])['Weekly_Sales'].mean()

# %%
sns.lineplot(weekly_sales_2010.index, weekly_sales_2010.values)
# Out:
# <AxesSubplot:xlabel='week'>

# %%
weekly_sales_2012 = df[df['year']==2012].groupby(['week'])['Weekly_Sales'].mean()

# %%
sns.lineplot(weekly_sales_2012.index, weekly_sales_2012.values,color='green')
# Out:
# <AxesSubplot:xlabel='week'>

# %%
### combined plot
plt.figure(figsize=(20,10))
sns.lineplot(weekly_sales_2010.index,weekly_sales_2010.values)
sns.lineplot(weekly_sales_2011.index,weekly_sales_2011.values)
sns.lineplot(weekly_sales_2012.index,weekly_sales_2012.values)
plt.grid()
plt.title('Average weekly sales per year',fontsize=30)
plt.ylabel('sales',fontsize=20)
plt.xlabel('weeks',fontsize=20)
plt.xticks(np.arange(1,60,step=1))
plt.legend(['2010','2011','2012'])

# %%
## data distribution of weekly sales
sns.distplot(df['Weekly_Sales'])
# Out:
# <AxesSubplot:xlabel='Weekly_Sales', ylabel='Density'>

# %%
### box plot
sns.boxplot(x = 'Type',y='Size',data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Size'>

# %%
## which 5 stores have highest average sales overall
weekly_sales_store = df.groupby(['Store'])['Weekly_Sales'].mean()

# %%
pd.DataFrame(weekly_sales_store).sort_values(by='Weekly_Sales',ascending=False).style.bar()
# Out:
# <style type="text/css">
# #T_8d51f_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_8d51f_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.8%, transparent 98.8%);
# }
# #T_8d51f_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 97.5%, transparent 97.5%);
# }
# #T_8d51f_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 92.7%, transparent 92.7%);
# }
# #T_8d51f_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 91.2%, transparent 91.2%);
# }
# #T_8d51f_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.2%, transparent 89.2%);
# }
# #T_8d51f_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 84.1%, transparent 84.1%);
# }
# #T_8d51f_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 74.3%, transparent 74.3%);
# }
# #T_8d51f_row8_col0 {
# ...

# %%
len(df.Store.unique())
# Out:
# 45

# %%
### bar graph having stores on x axis and avg weekly sales on y axis
### combined plot
plt.figure(figsize=(20,10))
sns.barplot(weekly_sales_store.index,weekly_sales_store.values,palette='dark')

plt.grid()
plt.title('Average weekly sales per store',fontsize=30)
plt.ylabel('sales',fontsize=20)
plt.xlabel('stores',fontsize=20)
# Out:
# Text(0.5, 0, 'stores')

# %%
weekly_sales_dept = df.groupby(['Dept'])['Weekly_Sales'].mean()
plt.figure(figsize=(20,10))
sns.barplot(weekly_sales_dept.index,weekly_sales_dept.values,palette='dark')

plt.grid()
plt.title('Average weekly sales per dept',fontsize=30)
plt.ylabel('sales',fontsize=20)
plt.xlabel('dept',fontsize=20)
# Out:
# Text(0.5, 0, 'dept')

# %%
weekly_sales_dept.sort_values(ascending=False)
# Out:
# Dept
# 92    75204.870531
# 95    69824.423080
# 38    61090.619568
# 72    50566.515417
# 65    45441.706224
#           ...
# 51       21.931729
# 39       11.123750
# 78        7.296638
# 43        1.193333
# 47       -7.682554
# Name: Weekly_Sales, Length: 81, dtype: float64

# %%
######## heatmap of correlation matrix

## aryan shara
plt.figure(figsize=(20,8))
sns.heatmap(df.corr(),cmap = 'viridis',linewidths=2.0,linecolor = 'black',annot = True)
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5]),
#  [Text(0, 0.5, 'Store'),
#   Text(0, 1.5, 'Dept'),
#   Text(0, 2.5, 'Weekly_Sales'),
#   Text(0, 3.5, 'IsHoliday'),
#   Text(0, 4.5, 'Temperature'),
#   Text(0, 5.5, 'Fuel_Price'),
#   Text(0, 6.5, 'MarkDown1'),
#   Text(0, 7.5, 'MarkDown2'),
#   Text(0, 8.5, 'MarkDown3'),
#   Text(0, 9.5, 'MarkDown4'),
#   Text(0, 10.5, 'MarkDown5'),
#   Text(0, 11.5, 'CPI'),
#   Text(0, 12.5, 'Unemployment'),
#   Text(0, 13.5, 'Size'),
#   Text(0, 14.5, 'week'),
#   Text(0, 15.5, 'year')])

# %%
corr = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(corr, annot=True,cmap='magma')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df.corr(),cmap = 'rocket',linecolor = 'black',annot = True
)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20, 15))
sns.heatmap(df.corr(),cmap = 'magma',linewidths=2.0,linecolor = 'black',annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(18,8))
sns.heatmap(df.corr(),vmin=0.5,linecolor="black",linewidth=2, cmap="Greens",center=None, annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df.corr(), linewidth = 0.5 , cmap = 'coolwarm', linecolor = 'black', annot = True)  
plt.xticks(fontsize = 20)
plt.yticks(fontsize = 20)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5]),
#  [Text(0, 0.5, 'Store'),
#   Text(0, 1.5, 'Dept'),
#   Text(0, 2.5, 'Weekly_Sales'),
#   Text(0, 3.5, 'IsHoliday'),
#   Text(0, 4.5, 'Temperature'),
#   Text(0, 5.5, 'Fuel_Price'),
#   Text(0, 6.5, 'MarkDown1'),
#   Text(0, 7.5, 'MarkDown2'),
#   Text(0, 8.5, 'MarkDown3'),
#   Text(0, 9.5, 'MarkDown4'),
#   Text(0, 10.5, 'MarkDown5'),
#   Text(0, 11.5, 'CPI'),
#   Text(0, 12.5, 'Unemployment'),
#   Text(0, 13.5, 'Size'),
#   Text(0, 14.5, 'week'),
#   Text(0, 15.5, 'year')])

# %%
sns.set(rc = {'figure.figsize':(20,10)})
sns.heatmap(df.corr(), center=True,  annot=True, linewidths=5, linecolor='purple', cbar=True, cbar_ax=None, square=False, xticklabels='auto', yticklabels='auto', mask=None)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(),vmin=0.01,linecolor="black",linewidth=2, cmap="Greens",center=None, annot=True)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %%
sns.set(rc = {'figure.figsize':(20,10)})
sns.heatmap(df.corr(), center=True,cmap='magma',annot=True, linewidths=5, linecolor='black', cbar=True, cbar_ax=None, square=False, xticklabels='auto', yticklabels='auto', mask=None)
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1 2010-02-05      24924.50      False        42.31
# 1           1     2 2010-02-05      50605.27      False        42.31
# 2           1     3 2010-02-05      13740.12      False        42.31
# 3           1     4 2010-02-05      39954.04      False        42.31
# 4           1     5 2010-02-05      32229.38      False        42.31
# ...       ...   ...        ...           ...        ...          ...
# 421565     45    93 2012-10-26       2487.80      False        58.85
# 421566     45    94 2012-10-26       5203.31      False        58.85
# 421567     45    95 2012-10-26      56017.47      False        58.85
# 421568     45    97 2012-10-26       6817.48      False        58.85
# 421569     45    98 2012-10-26       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# ...

# %%
df.Fuel_Price.unique()
# Out:
# array([2.572, 2.548, 2.514, 2.561, 2.625, 2.667, 2.72 , 2.732, 2.719,
#        2.77 , 2.808, 2.795, 2.78 , 2.835, 2.854, 2.826, 2.759, 2.705,
#        2.668, 2.637, 2.653, 2.669, 2.642, 2.623, 2.608, 2.64 , 2.627,
#        2.692, 2.664, 2.619, 2.577, 2.565, 2.582, 2.624, 2.603, 2.633,
#        2.725, 2.716, 2.689, 2.728, 2.771, 2.735, 2.708, 2.843, 2.869,
#        2.886, 2.943, 2.976, 2.983, 3.016, 3.01 , 2.989, 3.022, 3.045,
#        3.065, 3.288, 3.459, 3.488, 3.473, 3.524, 3.622, 3.743, 3.807,
#        3.81 , 3.906, 3.899, 3.907, 3.786, 3.699, 3.648, 3.637, 3.594,
#        3.48 , 3.575, 3.651, 3.682, 3.684, 3.638, 3.554, 3.523, 3.533,
#        3.546, 3.526, 3.467, 3.355, 3.285, 3.274, 3.353, 3.372, 3.332,
#        3.297, 3.308, 3.236, 3.172, 3.158, 3.159, 3.112, 3.129, 3.157,
#        3.261, 3.268, 3.29 , 3.36 , 3.409, 3.51 , 3.555, 3.63 , 3.669,
#        3.734, 3.787, 3.845, 3.891, 3.877, 3.814, 3.749, 3.688, 3.561,
# ...

# %%
########################################################################################
#check the type of the stores with highest avg sales and check the type of 5 stores with lowest avergae sales
df[df['Store'].isin([20,4,14,13,2])]['Type'].value_counts()
# Out:
# A    51238
# Name: Type, dtype: int64

# %%
df[df['Store'].isin([33,5,44,3,38])]['Type'].value_counts()
# Out:
# B    18035
# C    14531
# A     6487
# Name: Type, dtype: int64

# %%
########## sales and type of stores
a = df.groupby(['Type'])['Weekly_Sales'].mean()
a
# Out:
# Type
# A    20099.568043
# B    12237.075977
# C     9519.532538
# Name: Weekly_Sales, dtype: float64

# %%
sns.barplot(a.index,a.values)
# Out:
# <AxesSubplot:xlabel='Type'>

# %% [raw]
# 1 higher the size more is the sales
# 2 each year almost same pattern so demand can be planned accordingly by considering last year's patterns
# 3 end year is having higher sales
# 4 store 20 having highest average sales
# 5 store 5 is having lowerst sales
# 5 dept 92 is having highest sales
# 6 dept 47 is having lowest sales
# 7 type a belongs to the larger stores
# 8 type c belongs to the smaller stores
